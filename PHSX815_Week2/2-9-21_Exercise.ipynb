# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#testing class code to ensure the functions run correctly

# %%
# %run ~/github/PHSX815_Week2/CoinToss.py -seed 5555 -prob 0.5 -Ntoss 10 -Nexp 10000 -output binom.txt
#additional argument: -output (which generates a txt file)
#function uses random.Bernoulli(prob) --> result is sum of independent Bernoulli random variables --> binomial

# %%
# %run ~/github/PHSX815_Week2/CoinAnalysis.py -prob0 0.5 -input0 binom.txt

#Nexp = number of experiments

# %% [markdown]
# -------

# %%
#applying categorical distribution random number sampling algorithm to CoinToss.py

# %%
# %run ~/github/PHSX815_Week2/CoinTossCat.py -seed 1322 -Ntoss 10 -Nexp 50000 -output cate.txt

# %%
# %run ~/github/PHSX815_Week2/CoinAnalysisCat.py -input0 cate.txt
# Out:
# 10.0
